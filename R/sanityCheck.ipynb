# %%
draw_hists <- function(file, restriction, stat){
    cs <- read.csv(file)
    r <- cs[cs$restr == restriction & cs$stat == stat, ]
    hist(r$epi)
    hist(r$env)
}

# %%
# Распределение p-values для фейковых наблюдений (белок целиком) - 1000 наблюдений, 1000 итераций

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_all_fdr", 100,"median_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_all_fdr", 100,"mean_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"

# %%
# то же для 200 наблюдений, 10000 итераций

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_200_fdr", 100,"median_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_200_fdr", 100,"mean_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"

# %%
# то же для 460 наблюдений, 10000 итераций

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_460new_fdr", 100,"median_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"

# %%
draw_hists("C:/Users/weidewind/Documents/CMD/Coevolution/Influenza/environment_or_epistasis/sanityCheck/h1_460new_fdr", 100,"mean_stat")
# Out:
# Plot with title "Histogram of r$epi"
# Plot with title "Histogram of r$env"
